# %% [markdown]
# <a href="https://colab.research.google.com/github/ADVAIT135/Artificial-Intelligence-ELL703_TW/blob/main/AI_EXP_4_Breadth_First_Search_and_Depth_First_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Name : ADVAIT GURUNATH CHAVAN, PRN : 4119008, Sem : 7, BE ELECTRONICS**
# # **Artificial Intelligence Lab, ELL703**
# # **Exp 4 : Implement any one of the Uninformed search techniques**
# # **Breadth First Search and Depth First Search**

# %% [markdown]
# # Without Using Dictionaries

# %% [markdown]
# # Implement Breadth First Search and Depth First Search for the given graph and compare the results with the given data

# %% [markdown]
# ![QS 1.png](data:image/png;base64,...)

# %% [markdown]
# ## Breath First Search

# %%
graph = {
  '5' : ['7','3'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['1'],
  '8' : [],
  '1' : []
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0) 
    print (m, end = " ") 

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)


print("Following is the Breadth-First Search")
bfs(visited, graph, '5')    # function calling
# Out:
# Following is the Breadth-First Search
# 5 7 3 8 2 4 1

# %% [markdown]
# ## Depth First Search

# %%
graph = {
  '5' : ['7','3'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['1'],
  '8' : [],
  '1' : []
}

visited = set() # List for visited nodes.

def dfs(visited, graph, node): #function for DFS
  if node not in visited:
    print(node, end = " ")
    visited.add(node)
    for neighbour in graph[node]:
      dfs(visited, graph, neighbour)
      


print("Following is the Breadth-First Search")
dfs(visited, graph, '5')    # function calling
# Out:
# Following is the Breadth-First Search
# 5 7 8 3 2 4 1

# %% [markdown]
# # Using Dictionaries

# %% [markdown]
# # Implement Breadth First Search and Depth First Search for the given data and compare the results with the given data
# ![QS 2.png](data:image/png;base64,...)

# %% [markdown]
# ## Breadth First Search Algorithm

# %%
graph = {
  'S' : ['A','B'],
  'A' : ['C', 'D'],
  'B' : ['E'],
  'C' : [],
  'D' : ['G','H'],
  'E' : [],
  'G' : [],
  'H' : []
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0) 
    print (m, end=" ") 

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

print("Following is the Breadth-First Search")
bfs(visited, graph, 'S')
# Out:
# Following is the Breadth-First Search
# S A B C D E G H

# %% [markdown]
# ## Depth First Search Algorithm

# %%
# Using a Python dictionary to act as an adjacency list
graph = {
  'S' : ['A','B'],
  'A' : ['C', 'D'],
  'B' : ['E'],
  'C' : [],
  'D' : ['G','H'],
  'E' : [],
  'G' : [],
  'H' : []
}

visited = set() # Set to keep track of visited nodes of graph.

def dfs(visited, graph, node):  #function for dfs 
    if node not in visited:
        print (node, end = " ")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

print("Following is the Depth-First Search")
dfs(visited, graph, 'S')
# Out:
# Following is the Depth-First Search
# S A C D G H B E
